# %%
import cv2
import torch
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\balan\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n-pose.pt")

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO Pose detection
    results = model(frame)

    # Draw keypoints on frame
    annotated_frame = results[0].plot()

    cv2.imshow("Posture Tracker", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'yolo11n-pose.pt'...
# 100%|██████████| 5.97M/5.97M [00:00<00:00, 55.8MB/s]
# 0: 480x640 1 person, 136.2ms
# Speed: 4.8ms preprocess, 136.2ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.3ms
# Speed: 1.3ms preprocess, 97.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.7ms
# Speed: 1.3ms preprocess, 82.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.4ms
# Speed: 1.8ms preprocess, 82.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.3ms
# Speed: 1.3ms preprocess, 76.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.0ms
# Speed: 1.2ms preprocess, 79.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.8ms
# Speed: 9.4ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.9ms
# Speed: 1.2ms preprocess, 80.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.1ms
# Speed: 1.5ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.0ms
# Speed: 1.4ms preprocess, 85.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.9ms
# Speed: 1.2ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.4ms
# Speed: 1.6ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.6ms
# Speed: 1.1ms preprocess, 75.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.1ms
# Speed: 1.2ms preprocess, 75.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.7ms
# Speed: 1.9ms preprocess, 74.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.9ms
# Speed: 1.5ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.3ms
# Speed: 1.8ms preprocess, 79.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.0ms
# Speed: 1.6ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.2ms
# Speed: 1.8ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.3ms
# Speed: 1.3ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.1ms
# Speed: 1.2ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.9ms
# Speed: 1.3ms preprocess, 69.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.0ms
# Speed: 1.1ms preprocess, 72.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.1ms
# Speed: 1.1ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.0ms
# Speed: 1.1ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.4ms
# Speed: 1.6ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.5ms
# Speed: 1.2ms preprocess, 74.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.4ms
# Speed: 1.1ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.9ms
# Speed: 2.1ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.8ms
# Speed: 1.6ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.3ms
# Speed: 1.2ms preprocess, 74.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.7ms
# Speed: 1.3ms preprocess, 72.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.8ms
# Speed: 1.3ms preprocess, 100.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.6ms
# Speed: 2.2ms preprocess, 88.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.3ms
# Speed: 1.1ms preprocess, 77.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.7ms
# Speed: 1.2ms preprocess, 74.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.1ms
# Speed: 1.0ms preprocess, 74.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.3ms
# Speed: 1.1ms preprocess, 78.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.2ms
# Speed: 1.1ms preprocess, 73.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.3ms
# Speed: 1.2ms preprocess, 74.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.5ms
# Speed: 1.7ms preprocess, 104.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.5ms
# Speed: 1.2ms preprocess, 74.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.6ms
# Speed: 1.5ms preprocess, 71.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.4ms
# Speed: 1.3ms preprocess, 71.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.0ms
# Speed: 1.9ms preprocess, 87.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person,
3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.8ms
# Speed: 1.3ms preprocess, 76.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.5ms
# Speed: 1.1ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.0ms
# Speed: 1.2ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.9ms
# Speed: 1.3ms preprocess, 78.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.4ms
# Speed: 1.5ms preprocess, 76.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.4ms
# Speed: 1.6ms preprocess, 76.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.8ms
# Speed: 1.1ms preprocess, 79.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.2ms
# Speed: 2.0ms preprocess, 85.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.4ms
# Speed: 1.3ms preprocess, 85.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.2ms
# Speed: 1.2ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.6ms
# Speed: 1.3ms preprocess, 78.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.1ms
# Speed: 1.5ms preprocess, 76.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.6ms
# Speed: 1.1ms preprocess, 109.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.5ms
# Speed: 1.2ms preprocess, 72.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.9ms
# Speed: 1.1ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.9ms
# Speed: 1.2ms preprocess, 72.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.1ms
# Speed: 2.5ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.3ms
# Speed: 1.7ms preprocess, 98.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.4ms
# Speed: 1.4ms preprocess, 91.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.3ms
# Speed: 1.7ms preprocess, 104.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.5ms
# Speed: 1.4ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.3ms
# Speed: 1.1ms preprocess, 79.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.7ms
# Speed: 1.4ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.2ms
# Speed: 1.2ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.6ms
# Speed: 1.3ms preprocess, 74.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       8     break
#      10 # Run YOLO Pose detection
# ---> 11 results = model(frame)
#      13 # Draw keypoints on frame
#      14 annotated_frame = results[0].plot()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)
#     180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\engine\model.py:560, in Model.predict(self, source, stream, predictor, **kwargs)
#     558 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559     self.predictor.set_prompts(prompts)
# --> 560 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\engine\predictor.py:175, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     173     return self.stream_inference(source, model, *args, **kwargs)
#     174 else:
# --> 175     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\engine\predictor.py:261, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     259 # Inference
#     260 with profilers[1]:
# --> 261     preds = self.inference(im, *args, **kwargs)
#     262     if self.args.embed:
#     263         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\engine\predictor.py:145, in BasePredictor.inference(self, im, *args, **kwargs)
#     139 """Runs inference on a given image using the specified model and arguments."""
#     140 visualize = (
#     141     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     142     if self.args.visualize and (not self.source_type.tensor)
#     143     else False
#     144 )
# --> 145 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\nn\autobackend.py:556, in AutoBackend.forward(self, im, augment, visualize, embed)
#     554 # PyTorch
#     555 if self.pt or self.nn_module:
# --> 556     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     558 # TorchScript
#     559 elif self.jit:
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\nn\tasks.py:114, in BaseModel.forward(self, x, *args, **kwargs)
#     112 if isinstance(x, dict):  # for cases of training and validating while training.
#     113     return self.loss(x, *args, **kwargs)
# --> 114 return self.predict(x, *args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\nn\tasks.py:132, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     130 if augment:
#     131     return self._predict_augment(x)
# --> 132 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\nn\tasks.py:153, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     151 if profile:
#     152     self._profile_one_layer(m, x, dt)
# --> 153 x = m(x)  # run
#     154 y.append(x if m.i in self.save else None)  # save output
#     155 if visualize:
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\nn\modules\head.py:245, in Pose.forward(self, x)
#     243 """Perform forward pass through YOLO model and return predictions."""
#     244 bs = x[0].shape[0]  # batch size
# --> 245 kpt = torch.cat([self.cv4[i](x[i]).view(bs, self.nk, -1) for i in range(self.nl)], -1)  # (bs, 17*3, h*w)
#     246 x = Detect.forward(self, x)
#     247 if self.training:
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:55, in Conv.forward_fuse(self, x)
#      53 def forward_fuse(self, x):
#      54     """Apply convolution and activation without batch normalization."""
# ---> 55     return self.act(self.conv(x))
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\balan\code-repo\learning-post-estimation\.venv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
